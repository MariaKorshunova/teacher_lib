# %% [markdown]
# # Занятие 24. Формула полной вероятности. Формула Байеса

# %%
# Калькулятор решения задачи на формулу Байеса
p_h1 = 0.35
p_h2 = 0.43
p_h3 = 1 - p_h1 - p_h2
p_h4 = 0
p_a_h1 = 0.8
p_a_h2 = 0.8
p_a_h3 = 0.7
p_a_h4 = 0

p_a = p_h1 * p_a_h1 + p_h2 * p_a_h2 + p_h3 * p_a_h3 + p_h4 * p_a_h4
p_h1_a = p_h1 * p_a_h1 / p_a
p_h2_a = p_h2 * p_a_h2 / p_a
p_h3_a = p_h3 * p_a_h3 / p_a
p_h4_a = p_h4 * p_a_h4 / p_a


print("Проверка сумма вероятностей гипотез = 1: ", round(p_h1 + p_h2 + p_h3 + p_h4) == 1)
print("Вероятность события A =", round(p_a, 2))
print("Вероятность гипотезы H1 при условии A =", round(p_h1_a, 2))
print("Вероятность гипотезы H2 при условии A =", round(p_h2_a, 2))
print("Вероятность гипотезы H3 при условии A =", round(p_h3_a, 2))
1-0.35-0.43
# Out:
# Проверка сумма вероятностей гипотез = 1:  True
# Вероятность события A = 0.78
# Вероятность гипотезы H1 при условии A = 0.36
# Вероятность гипотезы H2 при условии A = 0.44
# Вероятность гипотезы H3 при условии A = 0.2
# 0.22000000000000003

# %% [markdown]
# ## Задачи
#
# ### Про ноутбуки
#
# В одном из корпусов вуза есть 20 аудиторий с проекторами, из которых 10 Epson, 6 Xiaomi и 4 Viewsonic.
# Вероятность того, что проектор этих производителей будут работать в течении трех лет без ремонта соответственно составляет 0,7 ; 0,8 и 0,9 .
# * Найдите вероятность того, что проектор из случайно выбранной аудитории будет работать без ремонта в течение трех лет.
# * Проектор в одной из аудиторий проработал без ремонта в течение трех лет. Какая вероятность того, что это проектор фирмы Epson? Фирмы Xiaomi? Фирмы Viewsonic?

# %% [markdown]
# ### Переход из секции в секцию
#
# Студенты некоего университета выбрали в качестве спортивных секций волейбол - 9 %, плавание - 11 %, остальные - тренажерный зал
# Вероятность перехода из одной секции в другую составляет 2% для волейболистов, 3% для пловцов и 3% для занимающихся в тренажерном зале.
# Случайно выбранный опрошенный студент перевелся в другую секцию. Какова вероятность того, что изначально он занимался плаванием?

# %% [markdown]
# ### Овощной салат
# По дороге домой мама всегда заходит в овощную лавку за овощами.
# Она всегда покупает определенное количество овощей, 45% из которых составляют огурцы, 20% - помидоры, а оставшееся количество - морковь.
# Подпортившимися из всех овощей оказалось  20% помидоров, 15% огурцов и 13% моркови.
# Попробовав вечерний салат, состоящий из трех ингредиентов, в семье поняли, что с салатом что-то не так.
# Какова вероятность того, что испортившимся овощем в салате оказался огурец?

# %% [markdown]
# ###  Шрек, осел и кот
# Шрек, осел и кот делают свечи из серы. Шрек делает 69% свечей, осел 13%, а кот все остальное. Свеча Шрека  окажется бракованной и не будет гореть в 5% случаев, у осла в 7% случаев, а у кота в 9% случаев. Принц купил свечу и ока оказалась с браком. Определите вероятность того, что эту свечу изготовил Шрек, осел или кот.

# %% [markdown]
# ### Опоздать на первую пару
# Мария ездит в университет в 50% случаев на метро, в 30% случаев на автобусе и в 20% случаев на такси.
# Вероятность опоздать на первую пару соответственно равны 0.01, 0.03 и 0.08. Какая вероятность того, что Мария опоздает на первую пару?
